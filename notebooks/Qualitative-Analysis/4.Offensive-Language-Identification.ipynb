# %% [markdown]
# # Import required Libraries

# %%
import pandas as pd
import re, os
import nltk
from nltk.corpus import stopwords

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd

# %% [markdown]
# # Path Variables

# %%
ground_truth_csv = "../../data/Qualitative/Hate Speech.csv"

# %%
ground_truth_csv
# Out:
# '../../data/Qualitative/Hate Speech.csv'

# %%
if os.path.exists(ground_truth_csv):
    df = pd.read_csv(ground_truth_csv)

# %% [markdown]
# # Basic Pre-process

# %%
def preprocess_tweet(text: str) -> str:
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'RT : ', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'(\n)+', ' ', text)
    text = re.sub(r'&#\d+;', ' ', text)
    text = re.sub(r' +', ' ', text)
    text = re.sub(r'#(\w+)', '', text)
    text = re.sub(r'&amp', 'and', text)
    text = re.sub(r'&(\w+);', '', text)
    text = re.sub(r'[^\w\s\d]+', '', text)
    text = text.lower()
    
    return text.strip()

# %%
if "processed_sentence" not in df.columns:
    df['processed_sentence'] = df['Text'].apply(preprocess_tweet)
    df.to_csv(ground_truth_csv, index=False)
else:
    df = pd.read_csv(ground_truth_csv)

# %%
df
# Out:
#                                                  Text Code-mix-language  \
# 0   Ada paavingala kgf oda vachathukaga engaluku y...     English-Tamil
# 1      dei kelthu kuthi ajith ivanya yaru nadika sona     English-Tamil
# 2                Trailer mokka da ajith kelatu payale     English-Tamil
# 3   Rajini poi thokula thoku itha Veda yaru Una ke...     English-Tamil
# 4              கடைசில rajini ய வச்சு செஞ்சுடிங்களே டா     English-Tamil
# ..                                                ...               ...
# 95  nuvvv atteee nakuuu chalaa pichiii prabhas I m...    English-Telugu
# 96  TELUGU సినిమా చరిత్రర్లో లో MAA PRABAS నీ ఓ గొ...    English-Telugu
# 97  ఇప్పటికీ కూడా ఈ ట్రైలర్ చూస్తుంటే రోమాలు నిక్క...    English-Telugu
# 98  ఒక మినీ మూవీ ఈ సినిమా....music takes to that l...    English-Telugu
# 99               2020 బాహుబలి ఫ్యాన్స్ like yesukondi    English-Telugu
#
#               Label                                 processed_sentence
# 0       Hate Speech  ada paavingala kgf oda vachathukaga engaluku y...
# 1       Hate Speech     dei kelthu kuthi ajith ivanya yaru nadika sona
# 2       Hate Speech               trailer mokka da ajith kelatu payale
# 3       Hate Speech  rajini poi thokula thoku itha veda yaru una ke...
# 4       Hate Speech                        கடசல rajini ய வசச சஞசடஙகள ட
# ..              ...                                                ...
# 95  Non-Hate Speech  nuvvv atteee nakuuu chalaa pichiii prabhas i m...
# 96  Non-Hate Speech  telugu సనమ చరతరరల ల maa prabas న ఓ గపప నటడగ నల...
# 97  Non-Hate Speech                  ఇపపటక కడ ఈ టరలర చసతట రమల నకకడచకటయ
# 98  Non-Hate Speech            ఒక మన మవ ఈ సనమmusic takes to that level
# 99  Non-Hate Speech                      2020 బహబల ఫయనస like yesukondi
#
# [100 rows x 4 columns]

# %% [markdown]
# # Offensive Language Identification

# %%
available_models = [
    ("xlmr", "xlm-roberta-base"),
    ("mdeberta", "MoritzLaurer/mDeBERTa-v3-base-mnli-xnli"),
    ("labse", "setu4993/LaBSE"),
    ("muril", "google/muril-base-cased")
]

# %%
# Encode sentences
def encode_sentences(tokenizer, model, sentences,device):
    encoded_input = tokenizer(sentences, padding=True, truncation=True, max_length=128, return_tensors='pt')
    encoded_input = encoded_input.to(device)
    with torch.no_grad():
        model_output = model(**encoded_input)
    return model_output.last_hidden_state[:, 0, :]

# Zero-shot prediction
def zero_shot_predict(texts, labels, label_description,  model_name):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    batch_size = 1000
    label_embeddings = encode_sentences(tokenizer, model, label_description,device)
    predicted_indices = []
    for start in range(0, len(texts), batch_size):
        end = start + batch_size
        batch_texts = texts[start:end]
        text_embeddings = encode_sentences(tokenizer, model, batch_texts, device)
        cosine_similarities = F.cosine_similarity(text_embeddings.unsqueeze(1), label_embeddings.unsqueeze(0), dim=2)
        predicted_indices += torch.argmax(cosine_similarities, dim=1).tolist()
    return [labels[i] for i in predicted_indices]

# %%
#  Choose the model here (1-based index): 1 = XLM-R, 2 = mDeBERTa, 3 = LaBSE, 4 = MuRIL
for index in range(1,5):
    df = pd.read_csv(ground_truth_csv)
    choose_model = index
    key, model_name = available_models[choose_model - 1]
    labels_list = ["Non-Hate Speech", "Hate Speech"]
    descriptions = ["not an offensive text", "an offensive text"]
    if key not in df.columns:
        df[key] = zero_shot_predict(df["Text"].tolist(), labels_list, descriptions, model_name=model_name)
        df.to_csv(ground_truth_csv, index=False)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
df
# Out:
#                                                  Text Code-mix-language  \
# 0   Ada paavingala kgf oda vachathukaga engaluku y...     English-Tamil
# 1      dei kelthu kuthi ajith ivanya yaru nadika sona     English-Tamil
# 2                Trailer mokka da ajith kelatu payale     English-Tamil
# 3   Rajini poi thokula thoku itha Veda yaru Una ke...     English-Tamil
# 4              கடைசில rajini ய வச்சு செஞ்சுடிங்களே டா     English-Tamil
# ..                                                ...               ...
# 95  nuvvv atteee nakuuu chalaa pichiii prabhas I m...    English-Telugu
# 96  TELUGU సినిమా చరిత్రర్లో లో MAA PRABAS నీ ఓ గొ...    English-Telugu
# 97  ఇప్పటికీ కూడా ఈ ట్రైలర్ చూస్తుంటే రోమాలు నిక్క...    English-Telugu
# 98  ఒక మినీ మూవీ ఈ సినిమా....music takes to that l...    English-Telugu
# 99               2020 బాహుబలి ఫ్యాన్స్ like yesukondi    English-Telugu
#
#               Label                                 processed_sentence  \
# 0       Hate Speech  ada paavingala kgf oda vachathukaga engaluku y...
# 1       Hate Speech     dei kelthu kuthi ajith ivanya yaru nadika sona
# 2       Hate Speech               trailer mokka da ajith kelatu payale
# 3       Hate Speech  rajini poi thokula thoku itha veda yaru una ke...
# 4       Hate Speech                        கடசல rajini ய வசச சஞசடஙகள ட
# ..              ...                                                ...
# 95  Non-Hate Speech  nuvvv atteee nakuuu chalaa pichiii prabhas i m...
# 96  Non-Hate Speech  telugu సనమ చరతరరల ల maa prabas న ఓ గపప నటడగ నల...
# 97  Non-Hate Speech                  ఇపపటక కడ ఈ టరలర చసతట రమల నకకడచకటయ
# 98  Non-Hate Speech            ఒక మన మవ ఈ సనమmusic takes to that level
# 99  Non-Hate Speech                      2020 బహబల ఫయనస like yesukondi
#
#                xlmr         mdeberta        labse            muril
# 0   Non-Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 1       Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 2       Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 3   Non-Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 4       Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# ..              ...              ...          ...              ...
# 95      Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 96      Hate Speech      Hate Speech  Hate Speech  Non-Hate Speech
# 97      Hate Speech      Hate Speech  Hate Speech  Non-Hate Speech
# 98      Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
# 99      Hate Speech  Non-Hate Speech  Hate Speech  Non-Hate Speech
#
# [100 rows x 8 columns]

# %% [markdown]
# # Evaluation

# %%
for index in range(1,5):
    choose_model = index
    key, model_name = available_models[choose_model - 1]
    all_true = df["Label"].tolist()
    all_pred = df[key].tolist()
    report = classification_report(all_true, all_pred, digits=4)
    print(f"\nCLASSIFICATION REPORT: {key}")
    print(report)
# Out:
# CLASSIFICATION REPORT: xlmr
#                  precision    recall  f1-score   support
#
#     Hate Speech     0.3103    0.3600    0.3333        50
# Non-Hate Speech     0.2381    0.2000    0.2174        50
#
#        accuracy                         0.2800       100
#       macro avg     0.2742    0.2800    0.2754       100
#    weighted avg     0.2742    0.2800    0.2754       100
#
#
# CLASSIFICATION REPORT: mdeberta
#                  precision    recall  f1-score   support
#
#     Hate Speech     0.2500    0.0600    0.0968        50
# Non-Hate Speech     0.4659    0.8200    0.5942        50
#
#        accuracy                         0.4400       100
#       macro avg     0.3580    0.4400    0.3455       100
#    weighted avg     0.3580    0.4400    0.3455       100
#
#
# CLASSIFICATION REPORT: labse
#                  precision    recall  f1-score   support
#
#     Hate Speech     0.4949    0.9800    0.6577        50
# Non-Hate Speech     0.0000    0.0000    0.0000        50
#
#        accuracy                         0.4900       100
#       macro avg     0.2475    0.4900    0.3289       100
#    weighted avg     0.2475    0.4900    0.3289       100
#
#
# CLASSIFICATION REPORT: muril
#                  precision    recall  f1-score   support
#
#     Hate Speech     0.0000    0.0000    0.0000        50
# Non-Hate Speech     0.5000    1.0000    0.6667        50
#
#        accuracy                         0.5000       100
#       macro avg     0.2500    0.5000    0.3333       100
#    weighted avg     0.2500    0.5000    0.3333       100
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
